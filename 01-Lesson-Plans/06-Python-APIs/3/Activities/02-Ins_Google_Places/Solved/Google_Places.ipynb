# %%
# Dependencies
import requests
import json

from config import key_dict
gkey = key_dict.get('maps')
if not gkey:
    raise ValueError("No maps API key found")

# %%
# geocoordinates
target_coordinates = "43.6187102, -116.2146068"
target_search = "Chinese food"
target_radius = 8000
target_type = "restaurant"

# set up a parameters dictionary
params = {
    "location": target_coordinates,
    "keyword": target_search,
    "radius": target_radius,
    "type": target_type,
    "key": gkey
}

# base url
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

# run a request using our params dictionary
response = requests.get(base_url, params=params)

# %%
# print the response url, avoid doing for public github repos in order to avoid exposing key
#print(response.url)

# %%
# convert response to json
places_data = response.json()

# Print the json (pretty printed)
print(json.dumps(places_data, indent=4, sort_keys=True))
# Out:
# {
#     "html_attributions": [],
#     "next_page_token": "ATtYBwKYNwOZBUrVMOZCbAXJJEJixA4Q1Pl4hwHDSlnxF5P9kA1hN1fGhm3gHmd2StZqlDg034D5QktEKoe7WtaWQ_6YXYJzi-UWGjMIqYoxWOh7ZkWaDpHcDPA0LNbki6VlX82xMRm_SPa4yujurEVNlXGLe7e4_EU1WQWfKXXaIEJEs4dNsu9ofrko7hQ3j4iRvYEYKG5hYXvJ-3Wlj9d3e55IbYjiucXvr4PGRDcDoR3wyjmVSlIA5Qn4Puy0BqycJrYd7siRy2cqzSLorwC1pIiMWMAXiCjm3cGMMJo-vKlSJmk9z5Di4KwgSZS5NxGxTUjTLbsvbDALeG0RZINZwyyCFGEm16_6FZcdPQYY8uTUM_hF6MCJk9QtMQ_OzLWLtpWwjY7mOtwBPHUAW3pnTHiQPGInh35dfmbbtkv59JcL4K7uE3jZtDCGMedhqAP8c4_v6yjd1vIC4pA",
#     "results": [
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 43.6251218,
#                     "lng": -116.2123933
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 43.62632297989272,
#                         "lng": -116.2111938701073
#                     },
#                     "southwest": {
#                         "lat": 43.62362332010727,
#                         "lng": -116.2138935298927
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png",
#             "name": "North End Chinese Restaurant",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 2448,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/102960671513587619713\">Nicholas DiPietro</a>"
#                     ],
#                     "photo_reference": "ATtYBwJ9e0jExjRDN0TSCgQ3bci9zD5EaHX2tBRnm5moAD04z32Bjvh_dlAox6lwidtRtdxnkkub4SAlW2j1xzMIRyxcPADsZ0tMYea4rS3S5zqF3DdrVRxFb8DrGj09vqKaWXF878M6t9DFky-WgGEDPn07wDw2hI6_3RJpJjB0eM6Gz2vb",
#                     "width": 3264
#                 }
#             ],
#             "place_id": "ChIJP5lMQNz4rlQRPRigHmorMWw",
#             "plus_code": {
#                 "compound_code": "JQGQ+22 Boise, Idaho",
#                 "global_code": "85M5JQGQ+22"
#             },
#             "price_level": 1,
#             "rating": 3.9,
#             "reference": "ChIJP5lMQNz4rlQRPRigHmorMWw",
#             "scope": "GOOGLE",
#             "types": [
#                 "meal_delivery",
#                 "restaurant",
#                 "food",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 217,
#             "vicinity": "1806 W State St #3955, Boise"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 43.5910063,
#                     "lng": -116.2900003
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 43.59235617989272,
#                         "lng": -116.2885996701073
#                     },
#                     "southwest": {
#                         "lat": 43.58965652010728,
#                         "lng": -116.2912993298927
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png",
#             "name": "Lucky Palace Chinese Restaurant",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 2534,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/116258063497492904062\">hyt5168</a>"
#                     ],
#                     "photo_reference": "ATtYBwK1fmtHS8J1slcA4ywOVC_gIMWh71PzIL-Mz6Y4b7IRkvDGcfptsbYpNim6vg4b47tGhju8nApVtAPyxQkDY23q64zdo6Y2Djh3WZ_6k_jNpgsCGyst_oAwSgfTxiZ7EXYhb0bVtoysGvl55QodIM1NEn0cOql5brfLVYomZsP363Af",
#                     "width": 4032
#                 }
#             ],
#             "place_id": "ChIJ5RKyTVZWrlQRY-t-LLVVQ9M",
#             "plus_code": {
#                 "compound_code": "HPR5+CX Boise, Idaho",
#                 "global_code": "85M5HPR5+CX"
#             },
#             "price_level": 2,
#             "rating": 3.9,
#             "reference": "ChIJ5RKyTVZWrlQRY-t-LLVVQ9M",
#             "scope": "GOOGLE",
#             "types": [
#                 "restaurant",
#                 "food",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 183,
#             "vicinity": "8630 W Overland Rd, Boise"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 43.6149025,
#                     "lng": -116.2427673
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 43.61625252989272,
#                         "lng": -116.2415218701072
#                     },
#                     "southwest": {
#                         "lat": 43.61355287010727,
#                         "lng": -116.2442215298927
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png",
#             "name": "Golden Star Restaurant",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 3024,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/104397275627907053084\">katy ng</a>"
#                     ],
#                     "photo_reference": "ATtYBwIM71KkJri3XwChWY7ebiZ5LWcFm0G7ezzfAtXvrsybUfbd0RnYdGU6-nN44E448bFbwTzxHe8YRuO0EE_grFk1Do_jESRDWGfcghNY7OTGSbJ9VBHtdGJU-4OTuwTUbv7vv08t86qEacnU8c6Hl1rd9MHer75mOa8vwjZK-0zRixE0",
#                     "width": 4032
#                 }
#             ],
#             "place_id": "ChIJTctsXaL4rlQRbC1U996y4-0",
#             "plus_code": {
#                 "compound_code": "JQ74+XV Boise, Idaho",
#                 "global_code": "85M5JQ74+XV"
#             },
#             "price_level": 2,
#             "rating": 4.3,
#             "reference": "ChIJTctsXaL4rlQRbC1U996y4-0",
#             "scope": "GOOGLE",
#             "types": [
#                 "restaurant",
#                 "food",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 739,
#             "vicinity": "1142 N Orchard St, Boise"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 43.5888893,
#                     "lng": -116.2776039
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 43.59032242989273,
#                         "lng": -116.2762745201073
#                     },
#                     "southwest": {
#                         "lat": 43.58762277010728,
#                         "lng": -116.2789741798927
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png",
#             "name": "Guang Zhou Restaurant",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 4032,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/115683889569422608978\">Greg Dennler</a>"
#                     ],
#                     "photo_reference": "ATtYBwKNTu5eKSY_SgHma8XUYHFVOZB12DzPh18-uOGZXj3c7oEkV8SmXWf2rnSESupFAvPAKj_kav3adOA_S1HZixgZbUBkePE0FslU58Qxd07czq-jGBuLz97ibetBLhOUtVb443uMs12uhGjlsGv9jQzvKUe8epKC-lwm5BFbr0DcFMir",
#                     "width": 3024
#                 }
#             ],
#             "place_id": "ChIJDT-7DlJWrlQRO7rtBTzZf6s",
#             "plus_code": {
#                 "compound_code": "HPQC+HX Boise, Idaho",
#                 "global_code": "85M5HPQC+HX"
#             },
#             "price_level": 1,
#             "rating": 4.1,
#             "reference": "ChIJDT-7DlJWrlQRO7rtBTzZf6s",
#             "scope": "GOOGLE",
#             "types": [
#                 "restaurant",
#                 "food",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 405,
#             "vicinity": "7609 W Overland Rd, Boise"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 43.6180738,
#                     "lng": -116.2031764
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 43.61938092989272,
#                         "lng": -116.2017260701073
#                     },
#                     "southwest": {
#                         "lat": 43.61668127010728,
#                         "lng": -116.2044257298928
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png",
#             "name": "Yen Ching Restaurant",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 2988,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/116537571893860483637\">Mark Bailey</a>"
#                     ],
#                     "photo_reference": "ATtYBwI4HRiuUVAZaUdFJ9PjKLoPIzmkaTqyHTY_xyGougeIWsz8VWAcHhGmTfZo-RvgG6UCi1D5PRl50BzOaF_lko-03JN1BwWVAUWeiGnWxI7YVEMr46kCaSlOMF9XcNW-Dp57ElaX4g9Vh054Sr9LkDc-MG5e4SO9RP84-HCtyg8lG6EO",
#                     "width": 5312
#                 }
#             ],
#             "place_id": "ChIJD1s29-P4rlQR0QVGxC9AWY0",
#             "plus_code": {
#                 "compound_code": "JQ9W+6P Boise, Idaho",
#                 "global_code": "85M5JQ9W+6P"
#             },
#             "price_level": 2,
#             "rating": 4.3,
#             "reference": "ChIJD1s29-P4rlQR0QVGxC9AWY0",
#             "scope": "GOOGLE",
#             "types": [
#                 "bar",
#                 "restaurant",
#                 "food",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 481,
#             "vicinity": "305 N 9th St, Boise"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 43.6200457,
#                     "lng": -116.3128558
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 43.62135552989272,
#                         "lng": -116.3112094701073
#                     },
#                     "southwest": {
#                         "lat": 43.61865587010728,
#                         "lng": -116.3139091298927
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png",
#             "name": "China Grand Buffet",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 2304,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/104519388601984807250\">Bobby Alexander Datingaling</a>"
#                     ],
#                     "photo_reference": "ATtYBwLt20_OXUqSx0WWhVH4rCgfCEN072t1_0jAu31-NKQqN0ylLoVXXofEKWXdHv2P7h5FIrsaTgek6-o98iPFiBxMbNEpiGbsdXed7_J_Lds8YMG1GcmMD1n697vP2c63t1wsmAH7PYiiAxZfs6VG81hR1LLC-rDtisNifzYy92XV8_-T",
#                     "width": 4096
#                 }
#             ],
#             "place_id": "ChIJTSFfGNRVrlQRuTYkj0zGqMM",
#             "plus_code": {
#                 "compound_code": "JMCP+2V Boise, Idaho",
#                 "global_code": "85M5JMCP+2V"
#             },
#             "price_level": 1,
#             "rating": 4.2,
#             "reference": "ChIJTSFfGNRVrlQRuTYkj0zGqMM",
#             "scope": "GOOGLE",
#             "types": [
#                 "restaurant",
#                 "food",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 2143,
#             "vicinity": "10498 W Fairview Ave, Boise"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 43.6136713,
#                     "lng": -116.2057373
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 43.61494772989272,
#                         "lng": -116.2042832701073
#                     },
#                     "southwest": {
#                         "lat": 43.61224807010728,
#                         "lng": -116.2069829298927
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png",
#             "name": "P.F. Chang's",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 1836,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/110579674607987580161\">Chatchawan Sukkha</a>"
#                     ],
#                     "photo_reference": "ATtYBwJghUpGmYgHeIVpyBvGQYRBooWHNED2eOX-vIdDF6OswifquASUNHtoNxWPJPa9GTPWvKIT08iXgeyvgVic0nblmUMGcxsCURMGYSIFMwpvcF_A1fziZYUEmXuT6NQMtAUcWWUsCp8NFpkuuoGpSNUJbuUUiREyfqDA7Hwo2BPyCpVA",
#                     "width": 3264
#                 }
#             ],
#             "place_id": "ChIJEVx3TeX4rlQR4QkPYThohEg",
#             "plus_code": {
#                 "compound_code": "JQ7V+FP Boise, Idaho",
#                 "global_code": "85M5JQ7V+FP"
#             },
#             "price_level": 2,
#             "rating": 4.2,
#             "reference": "ChIJEVx3TeX4rlQR4QkPYThohEg",
#             "scope": "GOOGLE",
#             "types": [
#                 "meal_takeaway",
#                 "restaurant",
#                 "food",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 1244,
#             "vicinity": "391 S 8th St, Boise"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 43.5915577,
#                     "lng": -116.3116912
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 43.59288132989272,
#                         "lng": -116.3106272201073
#                     },
#                     "southwest": {
#                         "lat": 43.59018167010728,
#                         "lng": -116.3133268798927
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png",
#             "name": "Great Wall Restaurant",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 1080,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/105303282592017155704\">B Campbell</a>"
#                     ],
#                     "photo_reference": "ATtYBwJCVN6_GYnxVXR4CTbii5a_5CdVIqxNs5tnOGMthDvzZDIsbxTBGsVzlqUu6Ji9nS-OMqGqcCV9rPY4my3sNkX-iPOnuzi-eyR6ib-cW9nZ3gpUDjpBQ-dHEMnDVgpN5qPXh3EYCKbXoaQ_0pafhZFHmTNTODe17FhGFoD-CCKgZvfA",
#                     "width": 1920
#                 }
#             ],
#             "place_id": "ChIJle9LyO5WrlQRyBqJqPmCLQI",
#             "plus_code": {
#                 "compound_code": "HMRQ+J8 Boise, Idaho",
#                 "global_code": "85M5HMRQ+J8"
#             },
#             "price_level": 1,
#             "rating": 3.8,
#             "reference": "ChIJle9LyO5WrlQRyBqJqPmCLQI",
#             "scope": "GOOGLE",
#             "types": [
#                 "meal_delivery",
#                 "meal_takeaway",
#                 "restaurant",
#                 "food",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 673,
#             "vicinity": "10398 W Overland Rd, Boise"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 43.6487584,
#                     "lng": -116.2461602
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 43.65001707989273,
#                         "lng": -116.2449462201072
#                     },
#                     "southwest": {
#                         "lat": 43.64731742010729,
#                         "lng": -116.2476458798927
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png",
#             "name": "New Garden Chinese Restaurant",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 4160,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/110284797720925008141\">A Google User</a>"
#                     ],
#                     "photo_reference": "ATtYBwKF9WGwJ-pqtBtgppdL_E0dW5ucvbz4KIJJtINQoqOjcnu0lT46wKPA7be8B72m_YO5ZGxYrWYTYc4tXHearBH36E0K6PcQ_WcZloJlw23K2KCdrWDCjChuT4uICfU-NyzQJPtA6rzSrGEu6V_EQkdCEiupR23CUx6VfhJldA32Du-8",
#                     "width": 3120
#                 }
#             ],
#             "place_id": "ChIJvwYXUDz_rlQRKpVyY618JMM",
#             "plus_code": {
#                 "compound_code": "JQX3+GG Boise, Idaho",
#                 "global_code": "85M5JQX3+GG"
#             },
#             "price_level": 1,
#             "rating": 4,
#             "reference": "ChIJvwYXUDz_rlQRKpVyY618JMM",
#             "scope": "GOOGLE",
#             "types": [
#                 "restaurant",
#                 "food",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 150,
#             "vicinity": "4624 W State St, Boise"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 43.5906484,
#                     "lng": -116.2801612
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 43.59195202989272,
#                         "lng": -116.2788579201073
#                     },
#                     "southwest": {
#                         "lat": 43.58925237010728,
#                         "lng": -116.2815575798927
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png",
#             "name": "Panda Express",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 4032,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/115683889569422608978\">Greg Dennler</a>"
#                     ],
#                     "photo_reference": "ATtYBwJrfLmmV_DRdLG79Zqu-yJaLGDx_nNtIKdgoz4yldJJmD1y24GFU7oKx0qRwzIHpbJCW8RIq-4tjBKR6ocyDnP70Y6A3WMwsBHctBhUK82bi6WsGH8ap_R5QKN_A9sNSQvP2MMG__EydPP-RVc8ZflVvXo0evkd53G8NNheZLxWN7Ab",
#                     "width": 3024
#                 }
#             ],
#             "place_id": "ChIJb15nIlJWrlQRcvGGNq_0WC8",
#             "plus_code": {
#                 "compound_code": "HPR9+7W Boise, Idaho",
#                 "global_code": "85M5HPR9+7W"
#             },
#             "price_level": 1,
#             "rating": 4.1,
#             "reference": "ChIJb15nIlJWrlQRcvGGNq_0WC8",
#             "scope": "GOOGLE",
#             "types": [
#                 "restaurant",
#                 "food",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 958,
#             "vicinity": "7804 W Overland Rd, Boise"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 43.6215454,
#                     "lng": -116.2180356
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 43.62301827989272,
#                         "lng": -116.2166851201073
#                     },
#                     "southwest": {
#                         "lat": 43.62031862010728,
#                         "lng": -116.2193847798927
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png",
#             "name": "Sushi Joy Asian Cuisine",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 2988,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/116403600914294680135\">M Phillips</a>"
#                     ],
#                     "photo_reference": "ATtYBwJv4PU1-QaLWoLomP_AECs_4WWG4JX5uE81MBWZ6DC9Y9IvePcxvJitk0ka3HLmhVua_zOYnBX8iE3d3r-kMGBCHwIzSOliRyQA8W0iUZQg14R-NbqJz30AdaX05ErwXrQwnfq0U_mJZ9xlfjmK15TLyZ7FMastz2s76493bkNbcFiD",
#                     "width": 5312
#                 }
#             ],
#             "place_id": "ChIJCavi88L4rlQR8mDWej59VVc",
#             "plus_code": {
#                 "compound_code": "JQCJ+JQ Boise, Idaho",
#                 "global_code": "85M5JQCJ+JQ"
#             },
#             "price_level": 2,
#             "rating": 4.5,
#             "reference": "ChIJCavi88L4rlQR8mDWej59VVc",
#             "scope": "GOOGLE",
#             "types": [
#                 "restaurant",
#                 "food",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 458,
#             "vicinity": "2275 W Main St, Boise"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 43.6128764,
#                     "lng": -116.2031451
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 43.61417077989272,
#                         "lng": -116.2018404701073
#                     },
#                     "southwest": {
#                         "lat": 43.61147112010728,
#                         "lng": -116.2045401298927
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png",
#             "name": "Panda Express",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 3036,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/117353903133578767077\">James Derderian</a>"
#                     ],
#                     "photo_reference": "ATtYBwJKCpYVeOm16c_VhlDBgMF-EAr7L0lybQAVDvMaTCrvnOEbNPRR_p5vtWtl6nCucMOSmizFXLvT_nnHJrB3n34tUl91QlRY-R9LQ9A1G3Jw-2bM9rxhqz-cIfk7p-rRmgA9tc3dlfOK-XXn4TQI5MWJG7oBGKSHN5cCnFnQRUugjovY",
#                     "width": 4048
#                 }
#             ],
#             "place_id": "ChIJkevL-_r4rlQRdCX2O8ZXDsM",
#             "plus_code": {
#                 "compound_code": "JQ7W+5P Boise, Idaho",
#                 "global_code": "85M5JQ7W+5P"
#             },
#             "price_level": 1,
#             "rating": 4,
#             "reference": "ChIJkevL-_r4rlQRdCX2O8ZXDsM",
#             "scope": "GOOGLE",
#             "types": [
#                 "restaurant",
#                 "food",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 204,
#             "vicinity": "601 W Front St, Boise"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 43.614921,
#                     "lng": -116.2838702
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 43.61633177989272,
#                         "lng": -116.2824680201073
#                     },
#                     "southwest": {
#                         "lat": 43.61363212010728,
#                         "lng": -116.2851676798928
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png",
#             "name": "Panda Express",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 3024,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/118350779690464862712\">Roxana Curtis</a>"
#                     ],
#                     "photo_reference": "ATtYBwInDdeZ2-IW7daRhitLL_TtEJHdtCckNq-ewqu6CjlXAm7oVn_7AS7pIWA3tMnP0TpOsi5RJWE4qElY9F0a6yV0Q0e09fulcNM4luqVID0uDWg6nPUfysKe1zkPKVCXaRZgafIbnE1r0ft6KUF4rcdFg5AJBfGsIsVy0QYRRFTlna62",
#                     "width": 4032
#                 }
#             ],
#             "place_id": "ChIJbdZEMQ1WrlQRcVfVf-Hl8g8",
#             "plus_code": {
#                 "compound_code": "JP78+XF Boise, Idaho",
#                 "global_code": "85M5JP78+XF"
#             },
#             "price_level": 1,
#             "rating": 4,
#             "reference": "ChIJbdZEMQ1WrlQRcVfVf-Hl8g8",
#             "scope": "GOOGLE",
#             "types": [
#                 "restaurant",
#                 "food",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 393,
#             "vicinity": "1124 N Milwaukee St, Boise"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 43.62829869999999,
#                     "lng": -116.2467501
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 43.62956087989272,
#                         "lng": -116.2455196201073
#                     },
#                     "southwest": {
#                         "lat": 43.62686122010728,
#                         "lng": -116.2482192798927
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png",
#             "name": "Golden Wok",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 4032,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/108564864349711743478\">Trang Pham</a>"
#                     ],
#                     "photo_reference": "ATtYBwIblacPlkTz0ZdY5-TNWFKVwNj_obzFAtR1q0CCMS4Otd1xfLlil52xNsQDEXz2iiY8cA8Zu6vcesuxQzU8dkN0CV9gGmO0zL9DVMWymLRIITCZQc7ZKWfQeRKgSJKip3x3SVSusp-rgXoa-iK_-wlww938nc1RibZ9FMrNcCWi4Efx",
#                     "width": 3024
#                 }
#             ],
#             "place_id": "ChIJ4-wGxrP4rlQRQBpLRX5r_t0",
#             "plus_code": {
#                 "compound_code": "JQH3+87 Boise, Idaho",
#                 "global_code": "85M5JQH3+87"
#             },
#             "price_level": 1,
#             "rating": 4,
#             "reference": "ChIJ4-wGxrP4rlQRQBpLRX5r_t0",
#             "scope": "GOOGLE",
#             "types": [
#                 "meal_delivery",
#                 "restaurant",
#                 "food",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 395,
#             "vicinity": "3948 W Chinden Blvd #6412, Boise"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 43.6123556,
#                     "lng": -116.2430374
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 43.61360837989272,
#                         "lng": -116.2416783201072
#                     },
#                     "southwest": {
#                         "lat": 43.61090872010728,
#                         "lng": -116.2443779798927
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png",
#             "name": "Wok-Inn Noodle",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 3036,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/107349115928492094203\">Praveen Vadakoot</a>"
#                     ],
#                     "photo_reference": "ATtYBwIR0XkHy0s618PmU4Pqf-xklTmpHHKRIFHV-swrLyD-n2Yj8KppajFWnHk25JDMkntLH-fXk-Lc4k6PrBdoWq_Ivk130rfbtwqLld9dSCwBkg3yXYgGS5bK-w6zYge19rSuBUafeRYI-2GvuOThd3WyW5tKczQGGwtg7_c7gWc7wvtV",
#                     "width": 4048
#                 }
#             ],
#             "place_id": "ChIJe9STjx9WrlQRnMGkKZFN9V4",
#             "plus_code": {
#                 "compound_code": "JQ64+WQ Boise, Idaho",
#                 "global_code": "85M5JQ64+WQ"
#             },
#             "price_level": 1,
#             "rating": 4.4,
#             "reference": "ChIJe9STjx9WrlQRnMGkKZFN9V4",
#             "scope": "GOOGLE",
#             "types": [
#                 "meal_takeaway",
#                 "restaurant",
#                 "food",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 248,
#             "vicinity": "4912 Emerald St, Boise"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 43.58963800000001,
#                     "lng": -116.216586
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 43.59098947989272,
#                         "lng": -116.2151422201073
#                     },
#                     "southwest": {
#                         "lat": 43.58828982010728,
#                         "lng": -116.2178418798927
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png",
#             "name": "Panda Garden",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 1908,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/106174110811765380336\">Jacob Keene</a>"
#                     ],
#                     "photo_reference": "ATtYBwL1CwOVh_cVzARpF5U8aoztRjfMdDoe8TX0_oaypS7fnBsKaZFKtVyrFDbY5GrV7MK9AHWtkRFgqHdt-rEmT0i4IwoPjgCc5h2jK-qPJdxFrIbeJyNImHDZVBXRzg8DZuwlyJHXvjFu3Yd0faIkNxvTcYz3bjqtofjekZ-6BMPkM7oH",
#                     "width": 4032
#                 }
#             ],
#             "place_id": "ChIJ2VoTQ3D4rlQR3UKIMJlQFeI",
#             "plus_code": {
#                 "compound_code": "HQQM+V9 Boise, Idaho",
#                 "global_code": "85M5HQQM+V9"
#             },
#             "price_level": 1,
#             "rating": 3.9,
#             "reference": "ChIJ2VoTQ3D4rlQR3UKIMJlQFeI",
#             "scope": "GOOGLE",
#             "types": [
#                 "restaurant",
#                 "food",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 354,
#             "vicinity": "2801 W Overland Rd, Boise"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 43.6653862,
#                     "lng": -116.2801056
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 43.66669357989272,
#                         "lng": -116.2787576201073
#                     },
#                     "southwest": {
#                         "lat": 43.66399392010727,
#                         "lng": -116.2814572798927
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png",
#             "name": "Panda Express",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 3024,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/108427894577938186722\">Xiaobai T</a>"
#                     ],
#                     "photo_reference": "ATtYBwJxK0ZX_AP_Zf4g4ME57wAVyMmBNP-jmmGnFhGcNKYgj6zN6AilZ5C_nFRf1mU_EiB1C8PC4nJPQneOWLfJShWMnqmif-rheawAQ4rlLJCrH_j73Qu_bKTuJu01gul5mTWZG8YF4azz_dZmgnCCOsq02GZdTxhZ2A6anxALbwpq-0dq",
#                     "width": 4032
#                 }
#             ],
#             "place_id": "ChIJLdWyiJ7_rlQRIRdU-1NWqEw",
#             "plus_code": {
#                 "compound_code": "MP89+5X Garden City, Idaho",
#                 "global_code": "85M5MP89+5X"
#             },
#             "price_level": 1,
#             "rating": 4.1,
#             "reference": "ChIJLdWyiJ7_rlQRIRdU-1NWqEw",
#             "scope": "GOOGLE",
#             "types": [
#                 "restaurant",
#                 "food",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 451,
#             "vicinity": "6675 N Glenwood St, Garden City"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 43.6028926,
#                     "lng": -116.2443826
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 43.60420827989272,
#                         "lng": -116.2430331701073
#                     },
#                     "southwest": {
#                         "lat": 43.60150862010727,
#                         "lng": -116.2457328298928
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png",
#             "name": "Mandarin Palace",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 2274,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/103311480146692398200\">A Google User</a>"
#                     ],
#                     "photo_reference": "ATtYBwKsGf6xNh2WGPUQtKkDlmPUGTUou3xhEG8ZQ7Ck6UUmaZiHF_VK6NlztCmMLyzJvhpHUx2cneqq4EYdmhUZU1KGhlKstObUzaQBaT93i53DgpkBRQ_5Tkh0H_j8f8jZH6G_bre_YEWD4uf0j8Ml7MBeSJlCJwcbh_mXpZlizIPqs8eh",
#                     "width": 3095
#                 }
#             ],
#             "place_id": "ChIJecwebShWrlQRo_MtO2S0rdA",
#             "plus_code": {
#                 "compound_code": "JQ34+56 Boise, Idaho",
#                 "global_code": "85M5JQ34+56"
#             },
#             "price_level": 1,
#             "rating": 3.8,
#             "reference": "ChIJecwebShWrlQRo_MtO2S0rdA",
#             "scope": "GOOGLE",
#             "types": [
#                 "restaurant",
#                 "food",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 235,
#             "vicinity": "5020 W. Franklin St., Boise"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 43.6050103,
#                     "lng": -116.2064403
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 43.60621417989272,
#                         "lng": -116.2051728701073
#                     },
#                     "southwest": {
#                         "lat": 43.60351452010728,
#                         "lng": -116.2078725298927
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png",
#             "name": "Panda Express",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "place_id": "ChIJbUOFwlj4rlQRZ_4alQLNUtE",
#             "plus_code": {
#                 "compound_code": "JQ4V+2C Boise, Idaho",
#                 "global_code": "85M5JQ4V+2C"
#             },
#             "price_level": 1,
#             "rating": 3.8,
#             "reference": "ChIJbUOFwlj4rlQRZ_4alQLNUtE",
#             "scope": "GOOGLE",
#             "types": [
#                 "restaurant",
#                 "food",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 45,
#             "vicinity": "1910 W University Dr, Boise"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 43.577295,
#                     "lng": -116.195009
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 43.57901292989273,
#                         "lng": -116.1936632701073
#                     },
#                     "southwest": {
#                         "lat": 43.57631327010728,
#                         "lng": -116.1963629298928
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png",
#             "name": "Season Wok",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 2952,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/104156735198363326200\">David Ku</a>"
#                     ],
#                     "photo_reference": "ATtYBwKNLf6A4VYJeM11ixo9RaIRI2KJupOcwXdrJw2bKNGX8Dok10-DssAu-7tf5lSluMq3wels9EjASsJSNURPF0hnOtdXjq4puaSEof2GmqhoaFC982JQuE-hmLSZKl50Ya_Zurk9SFN217pMsTCnjb8hmmTNhXNjkX81CcpBPYWPckCH",
#                     "width": 5248
#                 }
#             ],
#             "place_id": "ChIJ_9TdpxD4rlQRdg8ROoJbNSw",
#             "plus_code": {
#                 "compound_code": "HRG3+WX Boise, Idaho",
#                 "global_code": "85M5HRG3+WX"
#             },
#             "price_level": 1,
#             "rating": 3.4,
#             "reference": "ChIJ_9TdpxD4rlQRdg8ROoJbNSw",
#             "scope": "GOOGLE",
#             "types": [
#                 "meal_delivery",
#                 "restaurant",
#                 "food",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 141,
#             "vicinity": "2775 Broadway Ave, Boise"
#         }
#     ],
#     "status": "OK"
# }

# %%
# Print the name and address of the first restaurant that appears
print(places_data["results"][0]["name"])
print(places_data["results"][0]["vicinity"])
# Out:
# North End Chinese Restaurant
# 1806 W State St #3955, Boise
